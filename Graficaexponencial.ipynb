# %% [markdown]
# <a href="https://colab.research.google.com/github/CorreaMartinezLuisAngel/Metodos-Numericos-I/blob/main/Graficaexponencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Vamos a graficarla función $f(x)=e^{x^2}$

# %%
def f(x):
 return np.exp(x**2)
# Out:
# np.float64(2.718281828459045)

# %%
xx=np.linspace(0,1,100)
plt.plot(f(xx))
